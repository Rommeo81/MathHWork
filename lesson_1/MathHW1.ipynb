# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0, 10, 500)
k1=1
k2=5.2
plt.plot(x, np.cos(k1*x), marker=".")
plt.plot(x, np.cos(k2*x), marker="")
# print(x)
